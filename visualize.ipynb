    192,
    160,
    128,
    0,
    96,
    0,
    128,
    96,
    0,
    0,
    224,
    0,
    128,
    224,
    0,
    0,
    96,
    128,
    128,
    96,
    128,
    0,
    224,
    128,
    128,
    224,
    128,
    64,
    96,
    0,
    192,
    96,
    0,
    64,
    224,
    0,
    192,
    224,
    0,
    64,
    96,
    128,
    192,
    96,
    128,
    64,
    224,
    128,
    192,
    224,
    128,
    0,
    32,
    64,
    128,
    32,
    64,
    0,
    160,
    64,
    128,
    160,
    64,
    0,
    32,
    192,
    128,
    32,
    192,
    0,
    160,
    192,
    128,
    160,
    192,
    64,
    32,
    64,
    192,
    32,
    64,
    64,
    160,
    64,
    192,
    160,
    64,
    64,
    32,
    192,
    192,
    32,
    192,
    64,
    160,
    192,
    192,
    160,
    192,
    0,
    96,
    64,
    128,
    96,
    64,
    0,
    224,
    64,
    128,
    224,
    64,
    0,
    96,
    192,
    128,
    96,
    192,
    0,
    224,
    192,
    128,
    224,
    192,
    64,
    96,
    64,
    192,
    96,
    64,
    64,
    224,
    64,
    192,
    224,
    64,
    64,
    96,
    192,
    192,
    96,
    192,
    64,
    224,
    192,
    192,
    224,
    192,
    32,
    32,
    0,
    160,
    32,
    0,
    32,
    160,
    0,
    160,
    160,
    0,
    32,
    32,
    128,
    160,
    32,
    128,
    32,
    160,
    128,
    160,
    160,
    128,
    96,
    32,
    0,
    224,
    32,
    0,
    96,
    160,
    0,
    224,
    160,
    0,
    96,
    32,
    128,
    224,
    32,
    128,
    96,
    160,
    128,
    224,
    160,
    128,
    32,
    96,
    0,
    160,
    96,
    0,
    32,
    224,
    0,
    160,
    224,
    0,
    32,
    96,
    128,
    160,
    96,
    128,
    32,
    224,
    128,
    160,
    224,
    128,
    96,
    96,
    0,
    224,
    96,
    0,
    96,
    224,
    0,
    224,
    224,
    0,
    96,
    96,
    128,
    224,
    96,
    128,
    96,
    224,
    128,
    224,
    224,
    128,
    32,
    32,
    64,
    160,
    32,
    64,
    32,
    160,
    64,
    160,
    160,
    64,
    32,
    32,
    192,
    160,
    32,
    192,
    32,
    160,
    192,
    160,
    160,
    192,
    96,
    32,
    64,
    224,
    32,
    64,
    96,
    160,
    64,
    224,
    160,
    64,
    96,
    32,
    192,
    224,
    32,
    192,
    96,
    160,
    192,
    224,
    160,
    192,
    32,
    96,
    64,
    160,
    96,
    64,
    32,
    224,
    64,
    160,
    224,
    64,
    32,
    96,
    192,
    160,
    96,
    192,
    32,
    224,
    192,
    160,
    224,
    192,
    96,
    96,
    64,
    224,
    96,
    64,
    96,
    224,
    64,
    224,
    224,
    64,
    96,
    96,
    192,
    224,
    96,
    192,
    96,
    224,
    192,
    224,
    224,
    192,
]

# %%
from __future__ import annotations

import os
from typing import Optional

import numpy as np
from PIL import Image


def visualize(
    action_list: list[int],
    save_path: Optional[str] = None,
    image_height: int = 100,
    palette: list[int] = PALETTE,
) -> Image.Image:
    """Visualize action segmentation result (and save it if necessary).

    Args:
        action_list (list[int]):
            List containing action class id like [1, 1, 1, 0, 0, 2, 2, ....]
        save_path (Optional[str]):
            If `save_path` is given, the visualized image will be save at `save_path`.
        image_height (int, optional):
            The height of visualized image. Defaults to 100.
            Note that the width depends on the length of `action_list`.
        palette (list[int]):
            Color palette. Default to `PALETTE`, which are obtained from PascalVOC.

    Returns:
        Image.Image:
    """
    # convert to 2D array.
    array = np.array(action_list, dtype=np.uint8)
    array = np.tile(array, reps=(image_height, 1))

    # convert to an image using color palette.
    image = Image.fromarray(array)
    image = image.convert("P")
    image.putpalette(palette)

    if save_path is not None:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        image.save(save_path)

    return image

# %%
import torch
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
visualize(np.load("/home/ubuntu/local/asrf++/result/gtea/dataset-gtea_split-1/predictions/S1_Cheese_C1_gt.npy"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/local/Resnet50/venv/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:639, in _save(im, fp, filename)
#     638 try:
# --> 639     rawmode = RAWMODE[im.mode]
#     640 except KeyError as e:
#
# KeyError: 'P'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~/local/Resnet50/venv/lib/python3.8/site-packages/PIL/Image.py:643, in Image._repr_image(self, image_format, **kwargs)
#     642 try:
# --> 643     self.save(b, image_format, **kwargs)
#     644 except Exception as e:
#
# File ~/local/Resnet50/venv/lib/python3.8/site-packages/PIL/Image.py:2413, in Image.save(self, fp, format, **params)
#    2412 try:
# -> 2413     save_handler(self, fp, filename)
#    2414 except Exception:
#
# ...

# %%
visualize(np.load("/home/ubuntu/local/asrf++/result/gtea/dataset-gtea_split-1/predictions/S1_Cheese_C1_pred.npy"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/local/Resnet50/venv/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:639, in _save(im, fp, filename)
#     638 try:
# --> 639     rawmode = RAWMODE[im.mode]
#     640 except KeyError as e:
#
# KeyError: 'P'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~/local/Resnet50/venv/lib/python3.8/site-packages/PIL/Image.py:643, in Image._repr_image(self, image_format, **kwargs)
#     642 try:
# --> 643     self.save(b, image_format, **kwargs)
#     644 except Exception as e:
#
# File ~/local/Resnet50/venv/lib/python3.8/site-packages/PIL/Image.py:2413, in Image.save(self, fp, format, **params)
#    2412 try:
# -> 2413     save_handler(self, fp, filename)
#    2414 except Exception:
#
# ...

# %%
visualize(np.load("/home/ubuntu/local/asrf++/result/gtea/dataset-gtea_split-1/predictions/S1_Cheese_C1_refined_pred.npy"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/local/Resnet50/venv/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:639, in _save(im, fp, filename)
#     638 try:
# --> 639     rawmode = RAWMODE[im.mode]
#     640 except KeyError as e:
#
# KeyError: 'P'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~/local/Resnet50/venv/lib/python3.8/site-packages/PIL/Image.py:643, in Image._repr_image(self, image_format, **kwargs)
#     642 try:
# --> 643     self.save(b, image_format, **kwargs)
#     644 except Exception as e:
#
# File ~/local/Resnet50/venv/lib/python3.8/site-packages/PIL/Image.py:2413, in Image.save(self, fp, format, **params)
#    2412 try:
# -> 2413     save_handler(self, fp, filename)
#    2414 except Exception:
#
# ...

# %%
def viz_result(split, file): # split number (1-4 or 1-5), video name
    gt = np.load("/home/ubuntu/local/asrf++/result/gtea/dataset-gtea_split-"+str(split)+"/predictions/"+file+"_gt.npy")
    pred = np.load("/home/ubuntu/local/asrf++/result/gtea/dataset-gtea_split-"+str(split)+"/predictions/"+file+"_pred.npy")
    refined = np.load("/home/ubuntu/local/asrf++/result/gtea/dataset-gtea_split-"+str(split)+"/predictions/"+file+"_refined_pred.npy")

    gt_org = np.load("/home/ubuntu/local/asrf/result/gtea/dataset-gtea_split-"+str(split)+"/predictions/"+file+"_gt.npy")
    pred_org = np.load("/home/ubuntu/local/asrf/result/gtea/dataset-gtea_split-"+str(split)+"/predictions/"+file+"_pred.npy")
    refined_org = np.load("/home/ubuntu/local/asrf/result/gtea/dataset-gtea_split-"+str(split)+"/predictions/"+file+"_refined_pred.npy")


    gt_img = visualize(gt,image_height=100)
    pred_img = visualize(pred,image_height=100)
    refined_img = visualize(refined, image_height=100)

    gt_img_org = visualize(gt_org,image_height=100)
    pred_img_org = visualize(pred_org,image_height=100)
    refined_img_org = visualize(refined_org, image_height=100)

    fig = plt.figure(figsize=(6,2.5))
    fig.suptitle("Ground truth and Prediction from Original ASRF and Modified ASRF for " + file)
    ax1 = fig.add_subplot(322)
    ax1.imshow(gt_img)
    ax1.axis("off")
    ax1.set_title("Ground truth", size=7)
    ax2 = fig.add_subplot(324)
    ax2.imshow(pred_img)
    ax2.axis("off")
    ax2.set_title("Prediction", size=7)
    ax3 = fig.add_subplot(326)
    ax3.imshow(refined_img)
    ax3.axis("off")
    ax3.set_title("Refined Prediction", size=7)

    ax4 = fig.add_subplot(323)
    ax4.imshow(pred_img_org)
    ax4.axis("off")
    ax4.set_title("Prediction Original", size=7)
    ax5 = fig.add_subplot(325)
    ax5.imshow(refined_img_org)
    ax5.axis("off")
    ax5.set_title("Refined Prediction Original", size=7)
    ax6 = fig.add_subplot(321)
    ax6.imshow(gt_img)
    ax6.axis("off")
    ax6.set_title("Ground truth", size=7)
    fig.tight_layout()
    # fig.savefig("/home/ubuntu/data/MS-TCN2-master/analysis/gtea/" + file + ".png")
    print(file + " done")

# %%
viz_result(1,"S1_Coffee_C1")
# Out:
# S1_Coffee_C1 done
